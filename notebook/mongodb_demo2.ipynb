# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\rawat\\Downloads\\TweetDF.csv")
df.head(5)
# Out:
#    Unnamed: 0  polarity                                              tweet
# 0           0       0.0  Ufff, they`re all now offline (my moldavian fr...
# 1           1       0.0  I'm sacred of being lonely and i'm a little un...
# 2           2       1.0                     @Amaninazaini  why hello thar.
# 3           3       1.0                    @vegale Wow! Wow! Good to hear
# 4           4       0.0  on my way to the doc first blah... i need some...

# %%
df.shape
# Out:
# (120000, 3)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'polarity', 'tweet'], dtype='object')

# %%
df = df.drop(columns="Unnamed: 0")
df.columns
# Out:
# Index(['polarity', 'tweet'], dtype='object')

# %% [markdown]
# ### Converting to dictnory

# %%
data = df.to_dict(orient="records")
data
# Out:
# [{'polarity': 0.0,
#   'tweet': 'Ufff, they`re all now offline (my moldavian friends) '},
#  {'polarity': 0.0,
#   'tweet': "I'm sacred of being lonely and i'm a little unsure about some things right now "},
#  {'polarity': 1.0, 'tweet': '@Amaninazaini  why hello thar.'},
#  {'polarity': 1.0, 'tweet': '@vegale Wow! Wow! Good to hear '},
#  {'polarity': 0.0,
#   'tweet': 'on my way to the doc first blah... i need some love '},
#  {'polarity': 0.0,
#   'tweet': 'tweetdeck not picking up tweets - facebook only - mmm (via @scbutler) - Me too '},
#  {'polarity': 1.0,
#   'tweet': "God, i'm exhausting... came home with the sun rising! "},
#  {'polarity': 1.0,
#   'tweet': '@balmain_belle bad news on the rejections, but all you need is 1! '},
#  {'polarity': 0.0,
#   'tweet': '@wideawakewesley just went on Tesco site. Says product is discontinued '},
#  {'polarity': 1.0,
#   'tweet': 'Hello imsondag glad to see ya here! I will follow you now. Btw, nice background!! '},
#  {'polarity': 0.0, 'tweet': 'is feeling broken right now. '},
#  {'polarity': 0.0,
#   'tweet': "i sad i can't talk to the sweetest @babypatches tho  i have a dawggie crush on her pwetty face!  #pawpawty"},
#  {'polarity': 1.0,
#   'tweet': 'my mommy mad some bomb ass potatoes with cheese! mmmmmmmm...its such a fuckin nice day in So Cal today! '},
#  {'polarity': 1.0, 'tweet': '@Chilosa09 very nice '},
#  {'polarity': 0.0, 'tweet': "I'm still very sad "},
#  {'polarity': 0.0,
#   'tweet': 'My compassion to the people in italy! My mother is calling with our relatives in Italy right now  '},
#  {'polarity': 0.0,
#   'tweet': 'http://www.fast140.com/heartbomb I am still hoping though '},
#  {'polarity': 0.0, 'tweet': "it's april, it shouldn't be snowing anymore "},
#  {'polarity': 1.0,
#   'tweet': "mmmm pancakes haven't made those in awhile... oh i miss american brunches "},
#  {'polarity': 0.0,
#   'tweet': "Getting ready for an afternoon of events, then Guys movie night!  Might be fun. Just a tad jealous that Mary's going to the game... "},
#  {'polarity': 0.0, 'tweet': '@ANALOVESTITO  Clean Me!'},
#  {'polarity': 1.0,
#   'tweet': '@VioletDelirium Wait, she gets the indoor gig and you have the outdoor one '},
#  {'polarity': 0.0,
#   'tweet': '@theweaponislove  you need ibuprofen, oreos and an aloe vera plant.'},
#  {'polarity': 1.0,
#   'tweet': '#asot400 lets not forget &quot;in and out&quot; sunlounger track. its a make love song... '},
#  {'polarity': 0.0, 'tweet': 'SAT homework '},
#  {'polarity': 1.0,
#   'tweet': 'Good news from Cali: They overcame the issues; placed 10th &amp; won the communication award.  http://poisson.me.dal.ca/~dp_08_14/'},
#  {'polarity': 0.0,
#   'tweet': "i hurt my right hand, but i don't know where I hurt my hand  it just happened"},
#  {'polarity': 0.0, 'tweet': 'in the bed...still sick... '},
#  {'polarity': 1.0, 'tweet': 'hello cyberjaya, land of depression. '},
#  {'polarity': 1.0,
#   'tweet': 'is happy to have found her &quot;ben fire&quot; on twitter '},
#  {'polarity': 1.0, 'tweet': '@jazzimcg hey, did you ever get that pic? '},
#  {'polarity': 1.0,
#   'tweet': "@AngelaWB i'm glad your day went better, and i hope today is fantastic.   xo"},
#  {'polarity': 0.0,
#   'tweet': "@AlanCarr well i'm never one to pass up a dare but i can't get through on that fone number "},
#  {'polarity': 0.0,
#   'tweet': 'in my room watching VH1 and thinking about how fucked up my boyfriend is me '},
#  {'polarity': 1.0,
#   'tweet': "@tga1976 LOL It's called growing up  I was around in the rave days - been there - done all that "},
#  {'polarity': 0.0, 'tweet': 'Is really worried about igcse exams '},
#  {'polarity': 0.0,
#   'tweet': '@CSIMiamiJenny I know thats how i felt after givin them presents+them not appreciating it  Horatio is the real man LOL'},
#  {'polarity': 1.0,
#   'tweet': "@sayhello_walrus Corrupting the youth of yet another nation, I see.I was watching Zim too last night  Haven't called for lack of monies.x"},
#  {'polarity': 0.0,
#   'tweet': 'been sitting in bed for an hour. i REALLY need to do some work soon. '},
#  {'polarity': 1.0,
#   'tweet': '@Rocks4Ever no sweat  i have everything theyve released and i think its gunna be their best yet  have you seen them live?'},
#  {'polarity': 1.0,
#   'tweet': 'Ah - done with the yearly cleaning crew duty for the building I live in - now on to enjoying the rest of the sunday '},
#  {'polarity': 0.0, 'tweet': "It's already one o clock "},
#  {'polarity': 0.0,
#   'tweet': "@street_light he tried to follow  you but he can't from his phone "},
#  {'polarity': 0.0,
#   'tweet': "@Rsltruly When I asked my Mom she started yelling at me  And I'm not even doing anything today, it's fucking gay."},
#  {'polarity': 1.0,
#   'tweet': '@suecharlton Wow, Sue, you are the toppings queen!   Did you enjoy it?'},
#  {'polarity': 1.0,
#   'tweet': 'LOL whenever I say &quot;yesterday&quot; to S she has to question it by asking &quot;before this day?&quot;, &quot;after this day&quot; is tomorrow &amp; beyond also '},
#  {'polarity': 0.0,
#   'tweet': 'Its another gorgeous day outside. I will be admiring through my office window '},
#  {'polarity': 0.0, 'tweet': "@xoxojinni It's rainy here.. Spring is gone~ "},
#  {'polarity': 1.0,
#   'tweet': '@sabihkhan You expect delivery guy to do his homework before dumping leaflets? '},
#  {'polarity': 0.0,
#   'tweet': 'still trying to finish her PSY1111 essay  references, conclusion and a summary! will it ever end, getting to distracted by fb and twitter.'},
#  {'polarity': 0.0, 'tweet': 'No more drinking for me... '},
#  {'polarity': 0.0, 'tweet': 'Where is my Twilight dvd? '},
#  {'polarity': 0.0,
#   'tweet': 'Intense night today. A LOT of discussing, some story writing. No music though  #composer #plot #story #iproject'},
#  {'polarity': 1.0,
#   'tweet': "@susanboyle09 hallo Susan, thanks for following! I do hope you're getting to live your dreams "},
#  {'polarity': 1.0,
#   'tweet': '&quot;Who picks your clothes - Stevie Wonder?&quot; (via @ant4000b) '},
#  {'polarity': 0.0,
#   'tweet': 'Hmm back to school tomorrow, this is not good.  I could cry'},
#  {'polarity': 1.0,
#   'tweet': "@missingbits is he not the greatest weenie ever?  I'm so in love with him. "},
#  {'polarity': 1.0,
#   'tweet': '@Jrathbne hey, big fan  are you ever coming to Australia?x'},
#  {'polarity': 0.0,
#   'tweet': "@boomboxhearts  they're not in my phone which means my phone tarded out on me. it does this lots lately. no buttons work. waa. when home ?"},
#  {'polarity': 1.0,
#   'tweet': '@ankitb4u also @candychang is frm design. More in my following list  Gnite!'},
#  {'polarity': 0.0,
#   'tweet': '#ipl Out. Damn Jayawardene You Suck Big Time. U dont know how to play Cricket. U got Yuvraj Out. '},
#  {'polarity': 0.0,
#   'tweet': '@LeeannBB Anyone....  been a crap day here ... now 12am and I guess time for bed. up at 5am! How is lovely sunny UK?'},
#  {'polarity': 1.0, 'tweet': "I'm getting too old for this!  "},
#  {'polarity': 0.0,
#   'tweet': 'Woah. Guess Swine Flu has become a worldwide thing. '},
#  {'polarity': 1.0,
#   'tweet': "http://twitpic.com/3l47c - late at night in the beach ^^ such beautiful night... I'll never forget those days "},
#  {'polarity': 1.0,
#   'tweet': '1) Is realllllllly tired. 2) Has a little tummyache? :/ 3) Wish Mathias would wake the fuck up xD 4) Happy four month, babe, love you '},
#  {'polarity': 1.0,
#   'tweet': 'is like yes tomorrow is free scoop day and ben and jerrys....yum '},
#  {'polarity': 0.0, 'tweet': 'doing homework '},
#  {'polarity': 0.0, 'tweet': 'Ahhh, I think I have a splinter '},
#  {'polarity': 0.0, 'tweet': 'I think our coffee pot died '},
#  {'polarity': 0.0,
#   'tweet': "@shefal unfortunately I can't quite afford gold and diamonds...maybe one day in the distant future! "},
#  {'polarity': 0.0,
#   'tweet': "'s dad got kicked outta the rents room for snoring and now He's sleeping above my room so i can hear him  no sleep tonight."},
#  {'polarity': 0.0,
#   'tweet': "I've got the hurties today   Maybe I need to be on a tropical beach somewhere to feel better..."},
#  {'polarity': 1.0,
#   'tweet': "@hannahem There was an ad for Hanna Anderson catalogue on my twitter page!! Isn't that what you were named after?! "},
#  {'polarity': 1.0,
#   'tweet': '@allsorts29 hiya, hope you and the family are well. Im due in less than three weeks eek '},
#  {'polarity': 0.0,
#   'tweet': "@crazybobbles but no..I sent you a picture on ze phone of why I was on edge...but you haven't got it?! NOOO "},
#  {'polarity': 0.0, 'tweet': "@davidcgarcia throat to 'just stop' "},
#  {'polarity': 0.0,
#   'tweet': "@Bethanrob2 Saw kate in town she has &quot;0% off facials i want o go but i doubt i'll be able to "},
#  {'polarity': 1.0,
#   'tweet': "@LOST_SKELETON That is for you to know. That's not my problem. I sleep now! "},
#  {'polarity': 1.0,
#   'tweet': '@ulul http://twitpic.com/3jjo5 - Lovely..her curious look is very cute '},
#  {'polarity': 0.0,
#   'tweet': 'the dogs at my parents keep waking me up at 6 am. '},
#  {'polarity': 1.0,
#   'tweet': 'My green turned out really pretty  I am pleased...even though I have hulk hands'},
#  {'polarity': 1.0, 'tweet': '@theendtime lmao i love me a good comedy '},
#  {'polarity': 1.0,
#   'tweet': 'I am home. @lilyroseallen ROCKED! Now bed... then me and my cold will spend tomorrow on the couch '},
#  {'polarity': 1.0, 'tweet': '@KanArieKArgzz i knoww . i aint dumbbb  LOL .'},
#  {'polarity': 0.0,
#   'tweet': '@question210 get on twitter already...damn! I miss my homie '},
#  {'polarity': 0.0,
#   'tweet': 'aaaaa guua mau the black parade is dead sooooooooo baaaaaaaaaaaad  '},
#  {'polarity': 0.0,
#   'tweet': 'I am so thirsty, but I spent all my money on cheap beer.  $6 bottled water or $2 beer from tap?'},
#  {'polarity': 1.0,
#   'tweet': "Just finished baking. Went over to dad's with some of the cinamon-rolls I made. He loved them "},
#  {'polarity': 0.0,
#   'tweet': "@Miss_Monrose Ouch  One good thing about living in Canada I 'spose, most of that is covered by government insurance."},
#  {'polarity': 1.0,
#   'tweet': '@chriswmiller http://twitpic.com/3luct - Pretty! Well, the ocean...not your legs '},
#  {'polarity': 0.0,
#   'tweet': 'tired from babysitting  drivers ed tomorrow ugh call or text'},
#  {'polarity': 0.0,
#   'tweet': 'I cant see anyones profile pictures.. is that happening in Twitter today? or is it my computer '},
#  {'polarity': 0.0,
#   'tweet': '@shaktijs gavar .........   i dont like gavar how can you eat that'},
#  {'polarity': 0.0,
#   'tweet': '@princessbuddha im having the same problem.. i never drive anymore! '},
#  {'polarity': 0.0,
#   'tweet': 'United beat on penalties. How sweet. Sorry Charlie '},
#  {'polarity': 0.0, 'tweet': '@lattyb Wow. In the office today?  Sucks man'},
#  {'polarity': 1.0, 'tweet': 'go doggies today!, kick west coast ass, lol '},
#  {'polarity': 1.0, 'tweet': '@MollieOfficial me 2 '},
#  {'polarity': 1.0, 'tweet': '@ctmini27 same thing phillies phans! '},
#  {'polarity': 1.0, 'tweet': 'Some more card designs coming very soon '},
#  {'polarity': 0.0,
#   'tweet': 'I almost burnt my French Toast because I was Twittering!  '},
#  {'polarity': 1.0,
#   'tweet': '@EmiRH Thats a sign that you have a soul that can easily be touched '},
#  {'polarity': 0.0, 'tweet': '@myssmodelstar  meany pants'},
#  {'polarity': 1.0, 'tweet': '@jeffpulver You welcome anytime ... '},
#  {'polarity': 0.0, 'tweet': '@pacowacoworld  i feel neglected now ;)'},
#  {'polarity': 0.0,
#   'tweet': "@MrFloydNL yep. As Ash said, it's reward for having faith in them early. I'd have bought one, but i had no cash  Oh well, i'll get 3 8&quot;ers"},
#  {'polarity': 1.0,
#   'tweet': "@pete173 Glad you're feeling affirmed about #c_of_e, we're alright on the whole "},
#  {'polarity': 1.0,
#   'tweet': 'I would just like to add that I didnt get up until 11.30 cos for 1 its a sunday, and 2 some idiot set off the fire alarm at 2.30am!!  hehe'},
#  {'polarity': 0.0,
#   'tweet': "I don't want to update because I have 69 updates.... but inevitable, I suppose. "},
#  {'polarity': 0.0,
#   'tweet': 'Ugh! Got that horrible sunday evening back to work feeling  made even worse by the fact i have had a week off! Boo!'},
#  {'polarity': 0.0, 'tweet': 'I am awake '},
#  {'polarity': 1.0,
#   'tweet': "@judyk113 Yeah, we're going to have neither, but it's all good. Hope you do. "},
#  {'polarity': 0.0,
#   'tweet': "Can't sleep because my hunny isn't here with me.  I know, it's mushy. Lol"},
#  {'polarity': 0.0,
#   'tweet': "@drhappymac I don't think the customer will be up for that unfortunately "},
#  {'polarity': 1.0, 'tweet': 'Drempt of him again.. '},
#  {'polarity': 1.0,
#   'tweet': 'makin TOO many updates...but i cant sleep...got a lot on my mind --&gt;&gt;make peace, joy, &amp; love, one love GOODNIGHT &lt;3 or morning  6am'},
#  {'polarity': 0.0,
#   'tweet': "I hate going to the library when it's closed, just to drop off books because I won't have a chance to go when it's open. "},
#  {'polarity': 0.0,
#   'tweet': "sat by the pool gutted watching H and Sam, gutted I can't join in this time "},
#  {'polarity': 1.0, 'tweet': 'In love with Coconut Records today...    &lt;3'},
#  {'polarity': 1.0,
#   'tweet': 'Getting ready--lunch--KD meeting--then HOMEEEEEEEEE! '},
#  {'polarity': 0.0,
#   'tweet': "@redeft hey, aloha to you too.  Sorry I was so loud this am.... didn't mean to be.  Tired and head hurts.  "},
#  {'polarity': 1.0,
#   'tweet': 'I am actually going to just delete wordpress in a minute! If ANYBODY uses wordpress, PLEASE TELL ME! '},
#  {'polarity': 0.0,
#   'tweet': 'is thinking what a great day this was for Cleveland sports but her precious Browns were left out and she is sad  #fb'},
#  {'polarity': 0.0, 'tweet': '@aunt_bunny whats wrong? '},
#  {'polarity': 0.0,
#   'tweet': 'is spending this BEAUTIFUL day inside of a library...yaaay '},
#  {'polarity': 0.0,
#   'tweet': "Hollis' death scene will hurt me severely to watch on film  wry is directors cut not out now?"},
#  {'polarity': 1.0,
#   'tweet': "@dougiemcfly morning  i'm really upset  my rabbit ran away last night  and the postman woke me up early  reply? ilu x."},
#  {'polarity': 1.0,
#   'tweet': '@Parakeeet Haha. The little perv. :p &lt;firm tone&gt;: P! Go to bed! Now! '},
#  {'polarity': 0.0,
#   'tweet': 'My right thumb cannot stop trembling because of tennis  ugh.'},
#  {'polarity': 1.0,
#   'tweet': 'applied for 4 jobs already zoom zoom looking for cheap london room to rent for 2 months prefer northern line '},
#  {'polarity': 1.0,
#   'tweet': "@irish1974 Though - that's not really a smile worthy event.... but the coincidence of it was.  Okay, I'm tired. Ignore me (as usual). "},
#  {'polarity': 0.0,
#   'tweet': 'Ok, so I am currently planning what the hell I am going to do now. TLD may not make it at this point. Poor show, had a good premise. '},
#  {'polarity': 0.0,
#   'tweet': "@georgewezsley good morning..I'm having church praise @ home this morning "},
#  {'polarity': 0.0,
#   'tweet': "I'm so upset with this phone  I hope it isn't broken for good. Stupid T-Mobile."},
#  {'polarity': 0.0,
#   'tweet': '@gerardway y is it that when u have the best intentions that people want 2 stab u Its so hard to keep it together when ur blood runs cold '},
#  {'polarity': 1.0,
#   'tweet': "@jodrell that is next on my list  I don't like twitterfic that much, and event box is too much."},
#  {'polarity': 0.0, 'tweet': '@searchjaunt yes, i know '},
#  {'polarity': 1.0,
#   'tweet': "miss seeing the artwork of my lamar's friend Nicole "},
#  {'polarity': 1.0,
#   'tweet': '@greekdude i thought you are a vegan as ur picture '},
#  {'polarity': 0.0,
#   'tweet': "It's Sunday! That means Lost tonight! I love Sundays for this reason, but it also means I have work tomorrow "},
#  {'polarity': 0.0,
#   'tweet': "so rylee,grace...wana go steve's party or not?? SADLY SINCE ITS EASTER I WNT B ABLE 2 DO MUCH  BUT OHH WELL....."},
#  {'polarity': 0.0,
#   'tweet': '@ryancarson  oh man!  make a FOWD in Luxembourg :-D'},
#  {'polarity': 0.0, 'tweet': '@87britbrat so do I '},
#  {'polarity': 1.0, 'tweet': 'i ate a very fat crab. YUM hahahaha! '},
#  {'polarity': 1.0,
#   'tweet': '@gollygeedamn I agree-some sweet typography and graphics! Looks good in any room '},
#  {'polarity': 1.0, 'tweet': '@mommybeebee and yes she is a great singer!!! '},
#  {'polarity': 1.0,
#   'tweet': "@canthelpmyself Let's co-write music tonight!!!!!! "},
#  {'polarity': 0.0, 'tweet': 'feeling a little under the weather today  boo!'},
#  {'polarity': 0.0,
#   'tweet': 'Last day before back to college! noo ive enjoyed being off so much! Going to write up my history essay and then maybe do some maths?! '},
#  {'polarity': 0.0, 'tweet': '@PoisonIvy69 wot u mean un young '},
#  {'polarity': 0.0,
#   'tweet': 'eek just saw the cause of the closure....car through fence and against pole totally trashed. '},
#  {'polarity': 1.0, 'tweet': 'watching the usual suspects.. woot! woot! '},
#  {'polarity': 1.0, 'tweet': 'Hoping for a nice day today! '},
#  {'polarity': 1.0,
#   'tweet': "@BryceBeatty I'm just saying, don't knock it till you try it. "},
#  {'polarity': 0.0, 'tweet': 'Losing at Risk. As usual '},
#  {'polarity': 0.0,
#   'tweet': "Just got in the car to do a quick shop .. discovered it's covered in bird sh*t  "},
#  {'polarity': 1.0,
#   'tweet': 'i need pelas... can you buy me the puta camara ? '},
#  {'polarity': 0.0, 'tweet': 'omg breech again *sob*   '},
#  {'polarity': 0.0,
#   'tweet': '@dividepictures Alas the nearest comic book store is 2 hours away by train. '},
#  {'polarity': 1.0,
#   'tweet': "@indiaknight @jojomoyes So long as that doesn't mean 'an opportunity to make you finish your maths homework at long last'. "},
#  {'polarity': 1.0, 'tweet': "tonight was fun  i've missed connor's banter!"},
#  {'polarity': 1.0,
#   'tweet': "ManojKiyan's songs on Loop.. BS Sasirekha is refreshing "},
#  {'polarity': 0.0,
#   'tweet': "Yep. That's what Anderson Cooper said. Bad form Mr. Cooper "},
#  {'polarity': 1.0,
#   'tweet': "is @ school.  --'  Just gaming and listening music  This is live.."},
#  {'polarity': 1.0,
#   'tweet': "is excited for two more sleeps any she doesn't have to wear the stupid goggles to bed anymore. "},
#  {'polarity': 0.0, 'tweet': 'I want watch a movie, but i dont find my DVD! '},
#  {'polarity': 1.0,
#   'tweet': "@allybang I'm so touched! you used our picture as your background!!! and please teach me how to upload a profile picture!! "},
#  {'polarity': 1.0,
#   'tweet': 'well, that was an unexpectedly delightful evening. @glory did stellar work, as always. '},
#  {'polarity': 0.0,
#   'tweet': "Check stef's facebook she is bragging about and the others....so pissed off..makes me not wanna go back because of all this crap "},
#  {'polarity': 1.0,
#   'tweet': 'Had a wicked holiday in yorkshire - and left my better half there for a few more days. Watched Deer Hunter and QofS as direct result '},
#  {'polarity': 0.0,
#   'tweet': '@yijieee I just started my slimming regime LOL v fatttttt  can we meet up for dinner!!!!!!'},
#  {'polarity': 0.0,
#   'tweet': '@PDXyogini and @soycamo : Is the &quot;Women + Tech == Yay!&quot; session really at the same time as the Yoga session?   #bcp3'},
#  {'polarity': 0.0,
#   'tweet': 'Ugh... Im awake. I want to sleep for just another hour '},
#  {'polarity': 0.0, 'tweet': 'im not a loser! '},
#  {'polarity': 1.0,
#   'tweet': '@ENUWBE you going with or she just taking the kids '},
#  {'polarity': 0.0,
#   'tweet': "@Dannymcfly Jonesy? McFLY MUST come to Germany. when you love Amsterdam you'll love Germany too. We're waiting for you!  please tweet back"},
#  {'polarity': 0.0, 'tweet': 'bsy today lot of work  '},
#  {'polarity': 0.0,
#   'tweet': '@krissyb  i hate it when it happens to me... never know what to do with myself - best to chill out, go for walks, etc.'},
#  {'polarity': 1.0,
#   'tweet': 'Twitter is like a facebook status no one can comment on, which is good because opinions annoy me '},
#  {'polarity': 1.0,
#   'tweet': 'getting ready to go up north, sister home tomorow '},
#  {'polarity': 1.0, 'tweet': "@nick_carter My god you're addict to it "},
#  {'polarity': 0.0, 'tweet': 'Okay wtf i cannot sleep '},
#  {'polarity': 1.0,
#   'tweet': '@dravine Welcome back!  I need to schedule a time to drop by to see your addition. '},
#  {'polarity': 0.0,
#   'tweet': 'I have resorted to taking my laptop with me in the van and pulling free WiFi from BurgerKing to try to finally get podcasts downloaded. '},
#  {'polarity': 0.0,
#   'tweet': "Phone is still out of action, they say until Tues/Wed - you're kidding me! Looks like I am going to have to give in and get a PAYG "},
#  {'polarity': 1.0,
#   'tweet': 'I just left the mall. Fina stunt. Ready to perform! '},
#  {'polarity': 0.0,
#   'tweet': "Figures, everyone's statuses indicate this was the best night of their lives, when it's one of the worsts nights of mine. "},
#  {'polarity': 0.0,
#   'tweet': "Hmmm... still up... haven't been able to sleep at all "},
#  {'polarity': 0.0,
#   'tweet': '@MizzChievouz Hey girl. The site is back.  Girlyvue is back and they have even more videos. '},
#  {'polarity': 0.0,
#   'tweet': '@laurzzzz Well. I had to get up at 12. My mumma woke me up. '},
#  {'polarity': 0.0,
#   'tweet': "Wow, sent an email to @internode yesterday with my questions about signing up, and they STILL haven't got back to me "},
#  {'polarity': 1.0,
#   'tweet': "@RightWingPirate And you're our favorite &quot;right wing conspiracy&quot; nut job! "},
#  {'polarity': 0.0,
#   'tweet': "I miss my husband and am sad he didn't contact me today.  "},
#  {'polarity': 1.0,
#   'tweet': 'has discovered that she loves easter crafts, eggs, hot cross buns... feel like watching the prince of egypt to aid my easter meditations '},
#  {'polarity': 1.0, 'tweet': '@MonaSmith 2006! '},
#  {'polarity': 1.0,
#   'tweet': 'Sweet... almost done with my &quot;Best Car for the Road&quot; post.  Will re-read later... but now am going climbing. '},
#  {'polarity': 1.0,
#   'tweet': "so I'm following 19 people and only have 1 follower...haha im a tool "},
#  {'polarity': 0.0, 'tweet': '@chelseabird Ouch. Bummer '},
#  {'polarity': 1.0,
#   'tweet': "ThinkN it's a Great Day to Skip off to the Royal's Home OpenR  C U THERE!!!"},
#  {'polarity': 0.0,
#   'tweet': '@kmaf i know and i even think i know that the guys are spelled like &quot;Figlarski&quot;, right?  or am i wrong? '},
#  {'polarity': 0.0,
#   'tweet': '@dizzyupthegirl I know what you mean.. its always like that in Malabon. '},
#  {'polarity': 1.0,
#   'tweet': "Ok people I am now on Facebook, I have caved to the peer pressure! Add me to your friends' list, K? "},
#  {'polarity': 0.0,
#   'tweet': "Watching one last episode of Doctor Who before hitting the books. Not because I want to, but that's the last DVD I received via Netflix. "},
#  {'polarity': 1.0, 'tweet': '@runnrgrl Sleep well and good luck to u2 '},
#  {'polarity': 1.0,
#   'tweet': "@Nellypt Good friend of mine, I'm also his personal assistant "},
#  {'polarity': 1.0,
#   'tweet': '@shaneaddinall i love you mwamwamwa have a blessed day '},
#  {'polarity': 1.0, 'tweet': '@kathrynbunghole no problem! '},
#  {'polarity': 1.0,
#   'tweet': '@MrStrider Its a great morning..er afternoon!  Abt to host open house. How are you today?'},
#  {'polarity': 1.0,
#   'tweet': 'Watching friends slowly catch up and move to and leverage Twitter... Btw to follow me more frequently follow @boomerangdata '},
#  {'polarity': 0.0, 'tweet': 'stomach ache '},
#  {'polarity': 1.0, 'tweet': 'Good Morning Twitter! Happy Monday '},
#  {'polarity': 1.0,
#   'tweet': '@writefast Not going to sleep just going to post something different, did you enjoy the quotes? '},
#  {'polarity': 0.0,
#   'tweet': '@thepunkbronxkid They were interviewing a lot of people.  I really hope I get hired.'},
#  {'polarity': 0.0,
#   'tweet': '@pauliniunia EXACTLY.i dont want them to tour.no no no they should stay in LA '},
#  {'polarity': 0.0,
#   'tweet': 'Dogs Marley &amp; Kaylee are at Pet Emergency for 12-24 hours - possible leaf toxicity (mold) got them. IV fluids are being pushed. '},
#  {'polarity': 1.0,
#   'tweet': '@dylan_mason ah! Jelous much! I am going to birmingham on the 21st may! You met any of them before?  xxx'},
#  {'polarity': 1.0,
#   'tweet': 'prom was effing amazing. i have the sweetest boy in the world '},
#  {'polarity': 1.0,
#   'tweet': "vibin' with Natasha Bedingfield...i'll make it great 2 be a man w/ a woman who can stand on every promise given makin vows 2 pls her man "},
#  {'polarity': 1.0,
#   'tweet': "@JonathanRKnight hmm you have a lot to say tonight! That's great!  Of course, here I am up late reading it. haha"},
#  {'polarity': 0.0,
#   'tweet': 'why did i have to miss all the snow in denver? i wanna play in the snow. '},
#  {'polarity': 0.0,
#   'tweet': 'driving to schiphol. apperantly I am not the only one. Stuck around aalsmeer '},
#  {'polarity': 1.0,
#   'tweet': 'Nice to see peeps changing their profile pics to actual pics of themselves *waves* Hiiiii! @180bysummer and @KyraKat '},
#  {'polarity': 0.0, 'tweet': "My god I feel rough! And I've got 3k run to do "},
#  {'polarity': 1.0,
#   'tweet': '@twittch Though I guess because Goku burried him it was all for the best... He would of died again in his grave. '},
#  {'polarity': 0.0, 'tweet': '9 people here, 3 GIANT banners to do.  fml'},
#  {'polarity': 1.0,
#   'tweet': 'Tune Hotels, has opened bookings for brand new rooms in its upcoming new hotels in Kuching. '},
#  {'polarity': 0.0, 'tweet': "There can't be more than 100 people here "},
#  {'polarity': 1.0,
#   'tweet': "@Tammi_LA Not for work...just for personal fulfillment!  I'll call/msg you tomorrow, maybe we can work something out!?"},
#  {'polarity': 1.0,
#   'tweet': '@danthedaddy I love that you &quot;tweeted&quot; Love You, Forever. '},
#  {'polarity': 1.0,
#   'tweet': '@johnnydina hehe use your imagination i have a lot of hidden talents '},
#  {'polarity': 1.0, 'tweet': "@NathanPederson So long as it's substance too. "},
#  {'polarity': 1.0,
#   'tweet': 'reading breaking dawn for the 3rd time  ooh EDWARD!'},
#  {'polarity': 1.0, 'tweet': '@framolamdu PYT is an excellent song '},
#  {'polarity': 1.0,
#   'tweet': '@Buildabear96 yeah  tehe. omj right now im watching twilight and edward just walked in *hyperventilates*rotfl. ;]'},
#  {'polarity': 1.0,
#   'tweet': "@amykay1 aww thats awesome!  I live in a false reality - i like 2 think i can sing but i cant, doesn't stop me from beltin it out n my car"},
#  {'polarity': 0.0,
#   'tweet': 'Even a four day week seems too long  I want to stay in bed!'},
#  {'polarity': 0.0, 'tweet': 'Morning everyone. Bad dream woke me up '},
#  {'polarity': 1.0,
#   'tweet': "Finally! For the first time as long as I can remember, I can breathe through my nose! It's the small successes which keep me going "},
#  {'polarity': 1.0,
#   'tweet': 'girls who spell night like &quot;niqht&quot; mentally drain me and i would rather not know you '},
#  {'polarity': 1.0,
#   'tweet': "@Schofe I've justheard about the demonstrations on the news. Good luck "},
#  {'polarity': 0.0, 'tweet': "Why can't I use my phone to update twitter "},
#  {'polarity': 0.0,
#   'tweet': "@LaureyStack awh...that's kinda sad  lol add me?? hello.kitty.65@hotmail.com"},
#  {'polarity': 0.0,
#   'tweet': 'I really wanted to clean today before work &amp; i dont have time so my husbands doing it all &amp; i was all  about it so he said hell leave'},
#  {'polarity': 0.0,
#   'tweet': 'furious not to loose weight  Eating too much grain, cereals nd not enough veggies to reduce my intake, and not enough exercising '},
#  {'polarity': 0.0,
#   'tweet': 'ya i need a shower btw and these ducks dont like me '},
#  {'polarity': 1.0, 'tweet': '@shaundiviney Mickey Mouse  hehe.'},
#  {'polarity': 0.0,
#   'tweet': "@MooseGurl I'm jealous. I keep having to dip into my savings "},
#  {'polarity': 0.0,
#   'tweet': "why can't i change my picture&gt;?!?!?!? arghhhh ... at work all day "},
#  {'polarity': 0.0, 'tweet': 'i cant sleep and rex cant text anymore '},
#  {'polarity': 0.0,
#   'tweet': 'http://twitpic.com/4drnv - MC Chris show..shitty quality '},
#  {'polarity': 1.0,
#   'tweet': 'To make or not to make a phone call to a potential competitor - always make it -it can turn into an opportunity. Sometimes. '},
#  {'polarity': 1.0,
#   'tweet': 'HAHAAHA The 3-match ODI series between Pakistan and Australia is called Chappal Cup.. err actually Chapal Cup! '},
#  {'polarity': 1.0,
#   'tweet': 'good to hear @porter_chris ,  that set made my night  #ASOT400'},
#  {'polarity': 1.0,
#   'tweet': '@chocolate_dip lol i wasnt complaining just making sure @yoeyfreshier wasnt getting off before me but @tivon cleared that up '},
#  {'polarity': 0.0, 'tweet': 'here we go againn.... '},
#  {'polarity': 0.0,
#   'tweet': 'NOO. PUSSYCAT DOLLS TICKETS GO ON SALE WHEN IM IN MANCHESTER FOR MCFLY BAD BAD TIMES. '},
#  {'polarity': 1.0,
#   'tweet': "@fluffypolo yah you're cool. And no I refuse to tell her. Lol keeding, ok I will. "},
#  {'polarity': 1.0,
#   'tweet': "Just saw the most amazing dance show ever and friends I haven't seen in a few weeks. Good night. "},
#  {'polarity': 1.0, 'tweet': "@Epi_Junky You're doing doubles this early? "},
#  {'polarity': 0.0, 'tweet': 'Dallas is warm, but no sun!!  '},
#  {'polarity': 0.0,
#   'tweet': '#Kaspa85 it was hit and miss.  I think it worked for a maximum of a couple hours but it was laggy and died every now and then  #asot400'},
#  {'polarity': 0.0,
#   'tweet': "The bus was supposed to leave 20 minutes ago, and it's not even HERE  yet! "},
#  {'polarity': 1.0, 'tweet': '@caterina999 shes taking her mom '},
#  {'polarity': 0.0,
#   'tweet': 'TAKIN IT DOWN....GOT A TUMMY ACHE  LONG DAII AHEAD OF ME 2MAR...NYTE NYTE TWITTIEz :-*'},
#  {'polarity': 1.0, 'tweet': '@Mike_Ace mine is on fb, and she loves it '},
#  {'polarity': 0.0, 'tweet': '@trvsbrkr I think I got that wrong sorry. '},
#  {'polarity': 1.0,
#   'tweet': '@sdalchemist Congrats  Now you welcome to the cook kids club ;)'},
#  {'polarity': 0.0,
#   'tweet': '@I_am_Beaker i mean whatevr. sorry itshard to spell. '},
#  {'polarity': 0.0, 'tweet': 'morning , going to the insurance company !! '},
#  {'polarity': 0.0,
#   'tweet': 'http://twitpic.com/4elz4 - Great day for a race. '},
#  {'polarity': 0.0,
#   'tweet': "@griffmiester no exchanging for me, my laptop hasn't arrived "},
#  {'polarity': 0.0,
#   'tweet': 'laying in bed watching shrek with kaden.. bbq-ing with my bf amanda tomorrow and letting the kids play.. poor steven has to work  ..'},
#  {'polarity': 0.0,
#   'tweet': "woke up early  couldn't get back to sleep. race later."},
#  {'polarity': 1.0, 'tweet': "Watching mtv's &quot; Taking the Stage&quot; "},
#  {'polarity': 1.0,
#   'tweet': '@Vero0228 I wish you guys would film her....talking about film....I still have those VHS tapes (dino tapes) of Kiandra  .....sorry =('},
#  {'polarity': 0.0,
#   'tweet': 'lifes just great , to bad school has to go and ruin it all next week ! '},
#  {'polarity': 0.0, 'tweet': 'Murray has lost the first set to Nadal. '},
#  {'polarity': 0.0,
#   'tweet': 'heading to Uni for her last ever UF training session in NUIM  how sad'},
#  {'polarity': 1.0,
#   'tweet': "@ehoust15 how's you today? Send me some motivation, with a bacon roll "},
#  {'polarity': 1.0,
#   'tweet': '@saigonnezumi awesome. 6 already answered me.. of, found this:Girls who love @saigonnezumi also prefer cannibals from the Fijis '},
#  {'polarity': 0.0,
#   'tweet': "@kiphakes http://twitpic.com/3ne7b - where's my cake?  Glad she's having a nice last day of her holiday! xxx"},
#  {'polarity': 0.0,
#   'tweet': "@RAHHburt screw those light skinned thangs. ::as if I'm not part of that army:: "},
#  {'polarity': 1.0,
#   'tweet': "@joyntheir  yeah, for sure! ....Oh, I like your bio about women and twitter's 140 "},
#  {'polarity': 0.0,
#   'tweet': "@AKSheridan @gt9 thanks! But I can't open it!  Some error keeps occuring"},
#  {'polarity': 0.0, 'tweet': 'wants to watch 17 Again! '},
#  {'polarity': 1.0, 'tweet': 'AP tour was BEEAASSTTT  &lt;333333333'},
#  {'polarity': 0.0,
#   'tweet': 'is SLEEPY....  Ready to go home and crawl in my nice warm bed!!'},
#  {'polarity': 1.0,
#   'tweet': '@aplusk loving how u always reply to people  very intresting'},
#  {'polarity': 0.0,
#   'tweet': "Good morning all tweeters, yes i knew this weekend's weather wouldn't last..  so sad back to another 3 days of rain and thunderstorms"},
#  {'polarity': 0.0, 'tweet': 'Got Twitter..   Only to follow colbert.'},
#  {'polarity': 1.0,
#   'tweet': '@Xanneroo Sounds great - will there be anymore TimeGhost podcasts? '},
#  {'polarity': 0.0,
#   'tweet': 'I almost avoided a 4 hour layover- missed getting on the 8am flight to PIA by a few minutes. Would have been nice to get home early.  '},
#  {'polarity': 1.0, 'tweet': '@nojokesfact flew my goldfish kite today '},
#  {'polarity': 1.0,
#   'tweet': 'webdotwizards night at the rushworth community house - webdotwiz is here early '},
#  {'polarity': 0.0,
#   'tweet': "I ALWAYS tweet this, but i miss my internet!  I'm so bored out of my mind. I dont wanna do hw &amp; i cant watch tv anymore bc I'm so behind."},
#  {'polarity': 1.0,
#   'tweet': '@TerriCook oww bless ya! I just laughed yet so not funny!Could just picture you doing it though! '},
#  {'polarity': 0.0, 'tweet': 'Iï¿½m fallin in... again. '},
#  {'polarity': 0.0,
#   'tweet': '@steeleworthy Ouch  Poor toes. We put them through too much.'},
#  {'polarity': 1.0,
#   'tweet': "@kristynmarie Oh, it's good to hear the snake's gone. "},
#  {'polarity': 0.0,
#   'tweet': '@Carol_Clements almost all smashed only have 3 left '},
#  {'polarity': 1.0,
#   'tweet': 'Gonna watch the HM movie (bad quality - gag -) and 17 Again (better quality, hopefully) today.  '},
#  {'polarity': 1.0, 'tweet': '@WeezyOfficial stay cool weezy '},
#  {'polarity': 0.0,
#   'tweet': "@BW101 it's brilliant, huh? disappointed that it won't be on the dvd too! Wish they filmed UCAP "},
#  {'polarity': 1.0,
#   'tweet': "@unahealy Hey Una. i love The Saturdays your fantastic  i can't wait for your next new album to come out (via @DanielT2009)"},
#  {'polarity': 1.0,
#   'tweet': "@davistbell you should move here brother.. I'm almost always in a good mood   http://twitpic.com/3j5b4"},
#  {'polarity': 0.0, 'tweet': "I was just told I'm old "},
#  {'polarity': 1.0,
#   'tweet': '@lukeshillabeer hey luke! cheers for the follow and for linking my blog on your website. '},
#  {'polarity': 1.0,
#   'tweet': "Logging out to attend mass.  The heat's making it unbearable for me to hear mass during my regular morning sked.  Until later... "},
#  {'polarity': 0.0,
#   'tweet': '@kennyhyder I absolutely agree! It didnt always use to be like that '},
#  {'polarity': 0.0, 'tweet': '@Nickxm sorry to hear '},
#  {'polarity': 1.0,
#   'tweet': 'just got up, its a lovely day..need to finish off a song then go to manchester and buy some clothes to take on tour  x'},
#  {'polarity': 0.0,
#   'tweet': 'off to do the wash, then home to nap, slept for crap, feel like shit '},
#  {'polarity': 0.0,
#   'tweet': 'Thanks to everyone for the kind words! Day one of being a graduate: load up in a van and drive to Philly for my last regatta. '},
#  {'polarity': 0.0,
#   'tweet': '@draganababy i sympathize with you, i have work tomorrow '},
#  {'polarity': 1.0,
#   'tweet': '@TomFelton seems  2 b fun guy, watching nick at nite ,almost 4 am here in massachusetts ,US.cold too brr have a good day  !!'},
#  {'polarity': 0.0,
#   'tweet': '@nessie111 awwh noo  Lets put a giant Cuddy toy in there :p'},
#  {'polarity': 1.0,
#   'tweet': 'was ment to be a really productive day... guess not! I did assault my hallway with post it notes though '},
#  {'polarity': 1.0,
#   'tweet': '@chriscornell hahahahaaaaa great word, the only one that will do in circumstance love it '},
#  {'polarity': 0.0,
#   'tweet': "@gcuniverse Cant' make any cards  I keep getting the Error Occurred Problem It comes as I go to the next page to do the verse "},
#  {'polarity': 1.0, 'tweet': "@buffybot85 i'm writing today also "},
#  {'polarity': 0.0,
#   'tweet': 'is so sleepy... having to put my @signtific efforts to bed for the night '},
#  {'polarity': 1.0,
#   'tweet': 'happy week! manchester visits from louby, bus bus, and clare bear '},
#  {'polarity': 0.0,
#   'tweet': ' I need to stop settling for less as of  right now. Seriously. Stay the fuck away from them. Spend all your money on shit that you want.'},
#  {'polarity': 0.0,
#   'tweet': "I'm trying to play some basketball right now but noone's down "},
#  {'polarity': 1.0,
#   'tweet': '@MariaPerotti How was the Speakeasy?  Did you dress &quot;era appropriate&quot;? I saw the website and looked very nice  '},
#  {'polarity': 0.0,
#   'tweet': 'When life hands you lemons make lemonade....yeah right, if only it were that simple! Wheres ddub with his positivity when I need him '},
#  {'polarity': 0.0,
#   'tweet': "huh? I thought Hells Kitchen was a Ramsay thing. Who's this nobody guy? Get Ramsay back. "},
#  {'polarity': 0.0,
#   'tweet': 'Watching Dirty Dancing. Favourite movie of all time. Sad that Patrick Swayze is so sick these days. '},
#  {'polarity': 1.0, 'tweet': '@GeriRosman ur quite welcome '},
#  {'polarity': 1.0,
#   'tweet': "Is awake at 5 am because I couldn't fall back asleep and nowni am listening to music RENT "},
#  {'polarity': 0.0,
#   'tweet': "@ktmurtha Oh no! What are the vital signs on yr phone's fight for life? Take out the battery to let it dry? "},
#  {'polarity': 0.0,
#   'tweet': 'Mitea is missing  http://apps.facebook.com/catbook/profile/view/6040269'},
#  {'polarity': 0.0,
#   'tweet': "lmao &quot;that's my biiiiiitch&quot; @sheistheb wish I was there "},
#  {'polarity': 0.0,
#   'tweet': '@gemsam RE: star trek - yes that is so uinfair  i agree'},
#  {'polarity': 0.0, 'tweet': 'has a headache '},
#  {'polarity': 1.0, 'tweet': 'Is having a freaking awesome weekend so far!  '},
#  {'polarity': 1.0,
#   'tweet': "@iantalbot That's where 7yo gets it from  He accused Hubbs of smelling like an elephant's bumhole last night. Le sigh."},
#  {'polarity': 1.0,
#   'tweet': "CONGRATS Always Miley!!!!  We're so proud of our site@"},
#  {'polarity': 0.0,
#   'tweet': '@minastefan ahh. i hate when the power goes out. '},
#  {'polarity': 1.0,
#   'tweet': 'just returned from BNI - KB great job  - but now removing axe from back, 1 member I think hates me'},
#  {'polarity': 0.0,
#   'tweet': '@twtad my password entered for the new account does not work?  DM me @blroffers'},
#  {'polarity': 1.0,
#   'tweet': "I'm ready for my close-up but I MIGHT  settle for 15 minutes of fame "},
#  {'polarity': 0.0,
#   'tweet': 'Its 10.45. I had 2 cup of coffee. Still miss my bed '},
#  {'polarity': 1.0,
#   'tweet': '@whitepony143 good to see ya on here, and good choice on the username '},
#  {'polarity': 1.0, 'tweet': '@xoxoshahirah Yeah.  i dunno how but yeah. '},
#  {'polarity': 1.0,
#   'tweet': '@666TheBeast666 its exactly the point that he had to, or it wouldnt be so  Ask me why... '},
#  {'polarity': 1.0,
#   'tweet': '@jamie_oliver had to work but enjoyed the sun and nice weather. Hope you &amp; your lil fam are doing well. '},
#  {'polarity': 0.0,
#   'tweet': 'Chating with my homies one i might never hear from again  shes a great girl but she cant make a Twitter or any thing idk'},
#  {'polarity': 1.0,
#   'tweet': 'LOVE IT!!!! COYB. nearly vommed during penalties but Howard u r a legend '},
#  {'polarity': 0.0,
#   'tweet': "All i can do right now is laugh. I should not be here right now i'm tired "},
#  {'polarity': 0.0, 'tweet': 'Wow home alone again... '},
#  {'polarity': 0.0, 'tweet': 'OMG What is going on with my YANKEES  21-4 '},
#  {'polarity': 1.0, 'tweet': '@mihuthelion hello mihuuu! '},
#  {'polarity': 0.0,
#   'tweet': 'is sad i have to go back and ur not gonna be there '},
#  {'polarity': 1.0, 'tweet': 'Headed to la plya '},
#  {'polarity': 1.0,
#   'tweet': 'room clean comin along nicely. think ill spend the evening ere being all cosy and cuddled up if a certain someone wants to come cuddle! '},
#  {'polarity': 1.0,
#   'tweet': "@stephenfry Seems like you're happy to be back in England. Your timing is, as always, impeccable re: the beautiful spring weather. Enjoy "},
#  {'polarity': 1.0, 'tweet': "@Su2ieQ13 But you're IMing with meeeeee. "},
#  {'polarity': 0.0, 'tweet': "@cinderella1623 That's depressing "},
#  {'polarity': 1.0,
#   'tweet': 'Last day!  Trivia tonight as well as pizza and cheap beer   woo hoo'},
#  {'polarity': 0.0, 'tweet': "deleting DM's. too much direct messages "},
#  {'polarity': 1.0,
#   'tweet': '@baylormum You know it! ;) &quot;See ya&quot; at @theroadshow in a bit '},
#  {'polarity': 1.0, 'tweet': 'just held some lambs...how cute?! '},
#  {'polarity': 0.0,
#   'tweet': '@eliohouse not for everyone unfortunately !!  someone pick up a copy for me, ok ??'},
#  {'polarity': 0.0,
#   'tweet': "@sweptbyforever I'm sorry  I wish u coulda come to orpheum. Love u!"},
#  {'polarity': 0.0,
#   'tweet': "I'm about to get ready for school. Woke up and my hair was STILL wet from washing it last night. No straightener today "},
#  {'polarity': 1.0, 'tweet': '@Don_J Mawwwwning '},
#  {'polarity': 0.0, 'tweet': 'In class, bored and hungry. '},
#  {'polarity': 1.0,
#   'tweet': 'it is.....the new charlie the unicorn   http://www.newgrounds.com/portal/view/490280'},
#  {'polarity': 0.0,
#   'tweet': "@kelleegreen Haha. I'm not racing this time  Going for support. Aren't I a good friend?!"},
#  {'polarity': 1.0,
#   'tweet': '@stevefrost Barcamp Sheff Website On its way any day now - Any volunteers what to help out with that? '},
#  {'polarity': 1.0, 'tweet': '@ILikeBubbles So super cute '},
#  {'polarity': 1.0, 'tweet': 'lookin for somethin to do '},
#  {'polarity': 1.0,
#   'tweet': "@theesco I'm now giving manvice if you missed it LoL http://gggkeri.blogspot.com/   "},
#  {'polarity': 1.0, 'tweet': '@anniekatrina the next iPhone to be sure '},
#  {'polarity': 1.0,
#   'tweet': "@mmitchelldaviss do you know what word is exactly in the middle of your name? Hell. What's that supposed to mean? "},
#  {'polarity': 0.0,
#   'tweet': 'I really want that little dog though...damn skeksis fools gotta ruin the party '},
#  {'polarity': 0.0,
#   'tweet': 'to-do lists are the bane of my life right now. they seem to have taken a life of their own, and are completely derailing mine. '},
#  {'polarity': 1.0,
#   'tweet': "Hoping I can get some good sleep tonight... Poor baby, I still feel bad. A nice warm lavender bath made her feel good though  she's tough!"},
#  {'polarity': 1.0,
#   'tweet': "@Bokul lol... that was a jhoke right ?? Get OpenOffice. Free to download and use  - No cracks, no piracy. Makes M$'s life hell"},
#  {'polarity': 0.0,
#   'tweet': "is working from home but wishing it was 'home time' "},
#  {'polarity': 0.0,
#   'tweet': "@wastethisnight  awe it's okay. and i'm leaving early! lol how fantastic. is colleen coming?"},
#  {'polarity': 0.0, 'tweet': "iphone's not working...I feel so alone "},
#  {'polarity': 1.0, 'tweet': '@lecrab Why? Tell me! '},
#  {'polarity': 0.0, 'tweet': 'Is awake, uni times, bad times '},
#  {'polarity': 1.0, 'tweet': 'Now Im Just bored '},
#  {'polarity': 0.0, 'tweet': 'Uuuggghhhh today is not a good day 4 me '},
#  {'polarity': 1.0,
#   'tweet': 'The weather is nice outside. Verry sunny  Hope it will stay that way'},
#  {'polarity': 0.0, 'tweet': 'I miss yall though '},
#  {'polarity': 1.0,
#   'tweet': 'Feels that good 2 get all my bitchin out of the way - makes me C what little I have 2 complain about '},
#  {'polarity': 0.0,
#   'tweet': "Getting ready Steven and Andrea's Engagement party tonight at North Lakes, smart/casual - not pirate "},
#  {'polarity': 1.0,
#   'tweet': "@K_night4me No I didn't see you but I was in a trance w/ the show. "},
#  {'polarity': 1.0,
#   'tweet': "The Fried Egg Hunt at lurveBite and MiaSnow's is officially over!! Thanks to all who came to visit and see our new shop locations.  "},
#  {'polarity': 0.0,
#   'tweet': 'Just trying to figure out what twitter is all about....none of my friends are on here '},
#  {'polarity': 0.0, 'tweet': 'too nice to work '},
#  {'polarity': 0.0,
#   'tweet': "Will go to the media markt now, wish you a wonderful stunning day. Here it begins to thunder and I'm afraid of thunderstorms "},
#  {'polarity': 1.0, 'tweet': '@mag_nation see you at the hive! Good luck! '},
#  {'polarity': 0.0, 'tweet': "is... ugh i so don't wanna go to work "},
#  {'polarity': 1.0,
#   'tweet': 'Just thinking and wondering...Time for the hot tub  Did you ever wonder how I have Leads coming out my ears? http://bitly.com/K6hU'},
#  {'polarity': 1.0,
#   'tweet': "@kartar   it's not like I have a lot to do, many people rushing around making me beautiful..."},
#  {'polarity': 0.0,
#   'tweet': 'I hate hat HATE how ever time I come back to San Antonio, my allergies act up.  I miss being able to wake up and breath. '},
#  {'polarity': 1.0,
#   'tweet': 'movie was bueno last night. still waiting on something from someone special '},
#  {'polarity': 0.0,
#   'tweet': '@MsClementine I wanted to say sorry about friday and i hope i didnt get you into trouble '},
#  {'polarity': 1.0, 'tweet': '@sueissilly gmorning how ya doin? '},
#  {'polarity': 0.0,
#   'tweet': '@MirkleyJo  i cant make it to the tour   they wont send the tickets on short notice cos they might not arrive on time  so im gonna have'},
#  {'polarity': 0.0,
#   'tweet': '@montefontaine yeah I did, I was a slacker over the winter &amp; gained 15 of the 50 pounds I lost since starting to work out, so ashamed '},
#  {'polarity': 0.0,
#   'tweet': 'I hate the 360 degree view mirrors in changing rooms. Now having a bad hair and fat day '},
#  {'polarity': 1.0,
#   'tweet': "@jogotatwitr hahaha... glad you're listening and following on here! "},
#  {'polarity': 0.0,
#   'tweet': "Can't sleep  I close my eyes and all  I see is work and a billion ideas moving in all directions."},
#  {'polarity': 0.0,
#   'tweet': "@mickeytake Schools still off here to, not back till Wednesday!   I've been ill most of the hols, so not been able to do anything "},
#  {'polarity': 0.0,
#   'tweet': "Finally finished the 'Immigrant' by Manju Kapur. She forget about Ananda towards the closing! The end only covered off Nina. "},
#  {'polarity': 1.0, 'tweet': '@nsjewel Can I bring my rubber ducky float? '},
#  {'polarity': 0.0,
#   'tweet': 'I had really weird nightmares where I was a ghost during the Alaskan Goldrush, fighting Aliens and UFOs! Thanks alot pepperoni pizza!  '},
#  {'polarity': 1.0, 'tweet': '@Sir_Almo  Hello to you too '},
#  {'polarity': 0.0,
#   'tweet': '@Lynchie555 footie result  Did not go my way at all'},
#  {'polarity': 1.0, 'tweet': '@Emsy thanks! '},
#  {'polarity': 0.0,
#   'tweet': 'At home now. Fun fun fun tell its time to return to the real world on monday '},
#  {'polarity': 0.0,
#   'tweet': "@darthcena I'll have to write a tutorial, hee!  I'm sad that it isn't being developed anymore. "},
#  {'polarity': 1.0,
#   'tweet': 'Katerina now joining Vasilis in studio with the latest gossip  http://tinyurl.com/as4opy'},
#  {'polarity': 0.0,
#   'tweet': '@queenbmakeup  i haven`t found a face cleanser/exfoliator that i`ve liked since. i have real oily skin so idk what to look for ! '},
#  {'polarity': 1.0, 'tweet': 'class ended 15mins early '},
#  {'polarity': 0.0,
#   'tweet': "@DonnieWahlberg You were all wonderful tonight.  (except 1. don't do 2 in the Morning with that vocoder bullcrap 2. danny had a shirt  )"},
#  {'polarity': 0.0,
#   'tweet': '@kenneyjacob There were a couple of misspelt #cocktup tweets too... [my deepest apologies for initiating it]. '},
#  {'polarity': 0.0,
#   'tweet': 'i miss you - miley cyrus it always makes me cry '},
#  {'polarity': 0.0,
#   'tweet': '@LoveMeagan how i mss the snippet hun?..wts it of may i ask?..i wanna hear '},
#  {'polarity': 0.0, 'tweet': '@tinkermom Thats really sad  poor baby'},
#  {'polarity': 0.0, 'tweet': '@missparys my bf hates me too '},
#  {'polarity': 0.0, 'tweet': 'Sad  I lost one of my idols Danny Gans, R.I.P.'},
#  {'polarity': 1.0,
#   'tweet': "WOW, i must say im ready for him: http://www.myspace.com/uniquestarpower it's someone new, it's what the music industry needs today  "},
#  {'polarity': 1.0,
#   'tweet': '@RevzNexus a fairy, this Easter morning. dnt know abt later, but will let u know '},
#  {'polarity': 1.0,
#   'tweet': '@Mike_Greening .Man - you need to get back on the horse. '},
#  {'polarity': 0.0, 'tweet': 'i think i caught a fever '},
#  {'polarity': 0.0,
#   'tweet': "He was going to invite one of his friends over that both my friend and I like but he couldn't come "},
#  {'polarity': 0.0, 'tweet': 'ahh back to the grid '},
#  {'polarity': 0.0, 'tweet': '@jimhat  hungry!'},
#  {'polarity': 1.0,
#   'tweet': 'Re-pinging @asexynyfemale: @MeGaBoAsT smile boo???? smiling now  I just bored need to do something'},
#  {'polarity': 0.0,
#   'tweet': 'Did absolutely nothing tonight after four full days of studying and writing exams...but alas tommorow holds another full day of studying '},
# ...
#  {'polarity': 1.0,
#   'tweet': '@scenariogirl I know one dog friendly office  We are working there. '},
#  {'polarity': 1.0,
#   'tweet': 'Moving on from that &quot;one&quot;... Now on to the next.... '},
#  {'polarity': 0.0,
#   'tweet': '@meladrama for some reason, hon, I only get about 50% of your tweets! '},
#  {'polarity': 0.0,
#   'tweet': '@mitamata Yeah. Good thing I work at 3PM. &gt;.&gt; When will you be on this side of the ocean? '},
#  {'polarity': 0.0,
#   'tweet': 'Waiting at the vet... I hope everything is ok... '},
#  {'polarity': 0.0,
#   'tweet': 'My friend Coco (Chris) had a party this weekend, and it seemed to have been awesome. FAIL. I wasnae there   '},
#  {'polarity': 1.0,
#   'tweet': '@yod9 Thanks tons man! Seems to b working  Now I must try it on my internet PC in the studio. Need to get u 2 work on my recording pc! ha!'},
#  {'polarity': 1.0,
#   'tweet': '@shift2demax - thanks for following me! I hope you have a fabulous day! '},
#  {'polarity': 0.0,
#   'tweet': 'North carolina baby!! Aint nothin stopping them but the nba draft '},
#  {'polarity': 0.0,
#   'tweet': 'Stuck at curledge when i just quite frankly want to go home. Still in a bad mood  xx'},
#  {'polarity': 1.0, 'tweet': "Going to my cousin's.. weee. "},
#  {'polarity': 1.0,
#   'tweet': "@JessikaSays aha , I'm washed , clothed and brushed "},
#  {'polarity': 0.0,
#   'tweet': 'A bit tired of the 24/7 cribfest that surrounds me  #fb'},
#  {'polarity': 0.0, 'tweet': 'feels that she will fall sick again.. '},
#  {'polarity': 0.0,
#   'tweet': "is having a hard time using Twitter. lol. I don't know how to write MRZCULLEN back "},
#  {'polarity': 1.0,
#   'tweet': 'So you think you can dance final tonight!! I hope Taliah wins  Yeah boii'},
#  {'polarity': 0.0,
#   'tweet': "@datkidpatrick lol I don't kno bout anything so I'm stuck here   I'm bout to jus buy drinks and get talkative"},
#  {'polarity': 0.0,
#   'tweet': "@big_blue_wolf Not yet, no. Doubt I'll get a chance to until tonight. Work's mental, thanks to BT cutting off 70,000 customers today "},
#  {'polarity': 1.0, 'tweet': '@StMarcSpa Or who? '},
#  {'polarity': 1.0,
#   'tweet': '@mileycyrus snap! except for the rainy part! shocking really, its not acctually raining in england! lol '},
#  {'polarity': 0.0, 'tweet': 'i just want to slack. '},
#  {'polarity': 0.0,
#   'tweet': 'eh. grandparents house. reading a supah cool book right now............ probably an update from my phone later. bad day already. '},
#  {'polarity': 1.0, 'tweet': 'thinks the ms-walk was fantastic '},
#  {'polarity': 0.0, 'tweet': 'holidays over  back to LIFE!!'},
#  {'polarity': 0.0, 'tweet': 'my whole body hurts  I hate being unfit hahaha'},
#  {'polarity': 0.0,
#   'tweet': "@iGary yea I landed it a while ago like. Havn't been on my board in a while though, bad back "},
#  {'polarity': 1.0, 'tweet': 'Playing capture the flag  fuck yeah'},
#  {'polarity': 1.0, 'tweet': "Good Night! I'm sleeping in tomorrow "},
#  {'polarity': 0.0,
#   'tweet': '@amy_mini Hahah no where near enough snow for a snow day. Just enough for cold. Plus Pitt never has snow days '},
#  {'polarity': 1.0,
#   'tweet': 'off to the riteaid... then time to make my list of what to do today... still loving spring break '},
#  {'polarity': 1.0,
#   'tweet': '@hewball is finally home  now for Brody to go to sleep and I can relax'},
#  {'polarity': 1.0,
#   'tweet': "SIttin at table with marly gossiping about other people's lives  "},
#  {'polarity': 0.0, 'tweet': '@mariee_ '},
#  {'polarity': 0.0,
#   'tweet': 'Crazy hot.crazy busy.crazy mother. Its gonna be a long day '},
#  {'polarity': 0.0,
#   'tweet': "@whitespot55 26 ODs from GHB forced the police to close the venue halfway through tyDi's closing set!!   #asot400"},
#  {'polarity': 0.0,
#   'tweet': '@SexyLexy54321 I dont wanna look like a clown!! lol I dont have yellow. '},
#  {'polarity': 1.0,
#   'tweet': "@PhillyD hope he's doing better. best reguards and get well wishes. "},
#  {'polarity': 0.0,
#   'tweet': "@jdakar lol.. No u didn't  that was a long one though rite? How u handling it?"},
#  {'polarity': 0.0,
#   'tweet': "@nick_carter Where's my shout out?? I told you the Pooh JOKE!  "},
#  {'polarity': 1.0,
#   'tweet': "@insertemolyric http://www.chesterfrench.com/buy/ now cmon....laugh  doooo it. you know you're laughing......"},
#  {'polarity': 1.0, 'tweet': 'eating cupcakes '},
#  {'polarity': 1.0, 'tweet': "Yea so I've gott a GF noww "},
#  {'polarity': 0.0,
#   'tweet': '@Eric_Chambers @ChubbyGayMan I feel like I have been shot in both shoulders... is that the same as tight? '},
#  {'polarity': 1.0,
#   'tweet': '@angel9293 I wana thank u soo much for tweeting friendly goth! appreciate that TONS!!!!  Thank u! hope ur weekend is awesome!'},
#  {'polarity': 1.0,
#   'tweet': '@sonialexandra The concept of truth is irrelevant to survival, but the truth is whatever works is regarded as truth. '},
#  {'polarity': 1.0, 'tweet': '@architectjohn did you steal it? '},
#  {'polarity': 0.0,
#   'tweet': 'learning all about some rather dull stuff for my assessments this week  ... but all signed off so working from home '},
#  {'polarity': 1.0,
#   'tweet': '@kabooosh Hey!  Just sent it. Wah. Using google chrome and it took way too long.'},
#  {'polarity': 0.0,
#   'tweet': 'Doing some daily quests in WOW before the Bulls playoff game.  I have a feeling this is going to be a long afternoon.  '},
#  {'polarity': 1.0, 'tweet': 'good morning  #fb'},
#  {'polarity': 0.0,
#   'tweet': "Sad I won't be @citcon Minneapolis at the end of the week  on the other hand, there is CITCON Paris in September! Yay! http://is.gd/q4HE"},
#  {'polarity': 1.0,
#   'tweet': 'I forgot how cute Easter could be...dying eggs with the kiddies all day '},
#  {'polarity': 1.0, 'tweet': 'Camping was fun, imagine that '},
#  {'polarity': 0.0,
#   'tweet': 'Pouring rain. Need to run long this a.m. &amp; waiting for it to let up. Jen hosting a bridal shower today, now moved indoors   This sucks.'},
#  {'polarity': 0.0,
#   'tweet': 'Morning. Relaxing before starting patient calls later on '},
#  {'polarity': 0.0,
#   'tweet': 'is rather worried abt certain things  but has her fingers crossed tht shes jus worryin 2 much but has 2 wait n c   ...love james lots!'},
#  {'polarity': 1.0,
#   'tweet': '@pittkethley I love &quot;dropping acid&quot;  It makes the minerals look so nice with little effort. My Hanksite has to be scrubbed in brine=hassle'},
#  {'polarity': 0.0,
#   'tweet': '@dougiemcfly Iï¿½m back at collage now  Be glad youï¿½re not doing AS Biology! Are you going to be going near Darlington today (NorthEast?)'},
#  {'polarity': 0.0, 'tweet': 'Trying to complete my assignments for Monday '},
#  {'polarity': 0.0,
#   'tweet': "i have the monday blues  nothing that beer can't fix! ice cold, kgo! adventure awaits."},
#  {'polarity': 1.0, 'tweet': '@itsMeeeech -- sounds fun! '},
#  {'polarity': 1.0, 'tweet': '@Nellypt  tweet ya tomorrow.'},
#  {'polarity': 1.0,
#   'tweet': "thinks it's time for New Zealand to turn away from the big political parties. Mount Albert for RAM? "},
#  {'polarity': 1.0,
#   'tweet': 'S U N   Work tomorrow...   I need money, lots of money! )'},
#  {'polarity': 1.0,
#   'tweet': "g'night tweeterss! have sweet dreams &lt;3  -  im off "},
#  {'polarity': 1.0,
#   'tweet': '@tommcfly http://twitpic.com/3iquy - Wow Amsterdam looks soo beautiful  The view is awesome Danny and the tree'},
#  {'polarity': 0.0, 'tweet': 'Dumping my bf '},
#  {'polarity': 0.0, 'tweet': 'work time '},
#  {'polarity': 0.0,
#   'tweet': "@abeeken Trust me, they've tried that before! (well, maybe not an aeroplane) got home and all my veg had been dug up "},
#  {'polarity': 0.0,
#   'tweet': '@medscholar08 Tours and trips seems to be a part of history now......and i think its not hiding sumwhere but its lost sumwhere '},
#  {'polarity': 0.0, 'tweet': 'missing my baby girl '},
#  {'polarity': 0.0,
#   'tweet': "@infobunny ps: i'm the thick, effeminate sounding one. "},
#  {'polarity': 0.0, 'tweet': '@leahjones wipers=cool cruise =/= cool '},
#  {'polarity': 0.0,
#   'tweet': "i think i mistakenly threw out my thumb drive when i was cleaning my apartment yesterday.  definitely won't do that again. clean, i mean."},
#  {'polarity': 1.0,
#   'tweet': 'Ok, focus, check review and email. and then work on another review and column '},
#  {'polarity': 1.0, 'tweet': '@Giffymini Oh good that u liked it. '},
#  {'polarity': 0.0,
#   'tweet': "wishes your phone hadn't been turned off!  http://plurk.com/p/oz68d"},
#  {'polarity': 1.0,
#   'tweet': "@rodrigo_grana heh.. I mean I drunk so much liquor recently.  No worries.  and hiro has gone today :'-("},
#  {'polarity': 0.0, 'tweet': 'Have a blinding headache am going back to bed '},
#  {'polarity': 0.0, 'tweet': 'Going sailing! In the rain '},
#  {'polarity': 1.0,
#   'tweet': '@EliseHearn WOO HOO!!!  See - the Wandering Men are educational, too! '},
#  {'polarity': 0.0, 'tweet': 'has a slight tummy ache '},
#  {'polarity': 1.0,
#   'tweet': '@belzillafirefox paul walker plays in 2 fast 2 furious 4  as the blonde one  YAYYYY'},
#  {'polarity': 0.0,
#   'tweet': "@segoox2 I've got no fucking clue lmao! Wher are you I wanted to sit with you  comeeeeee here!!!"},
#  {'polarity': 0.0, 'tweet': ' sutil  lost both front wheels.'},
#  {'polarity': 1.0,
#   'tweet': "@johnrackham I've told you my idea for the British Museum security guard and the mummies, haven't I? You're the inspiration for it. "},
#  {'polarity': 1.0,
#   'tweet': "The weekend is far too short.  Done with rehearsal and off to SOFTBALL   Afraid we'll be rained out!"},
#  {'polarity': 0.0,
#   'tweet': 'is done with lab report....ouch the 4 red bulls hurt my tummy... '},
#  {'polarity': 0.0, 'tweet': "@tamzyn that's shit! "},
#  {'polarity': 0.0,
#   'tweet': "I'm in the mood for some racing, so I'm just downloading iPhone apps to race  and plus I'm just really bored "},
#  {'polarity': 1.0,
#   'tweet': "@Mrgareth Thanks for the plug  Live vid links @Oracle_JAPAC &amp; Wendy's going to tweet w her paws @Wendy_Wendy #oracleopenworldtokyo"},
#  {'polarity': 0.0,
#   'tweet': 'My night; went to the bar, Felt up a marred woman, went home hard and alone '},
#  {'polarity': 0.0,
#   'tweet': '@cinnamonclouds   Have you recorded before, btw?'},
#  {'polarity': 0.0,
#   'tweet': "@Famoiely but it's the first time they do it in Germany  (btw. Hase=husband ;-))"},
#  {'polarity': 0.0,
#   'tweet': 'they have the bruins game on here. I can see the tv, but not really. '},
#  {'polarity': 0.0,
#   'tweet': "@swarleyyy, you bitch! now i'm gonna have to watch the entire season alone, which was totally not the point in buying it "},
#  {'polarity': 0.0,
#   'tweet': "@joanikin Seemingly @tomwaits' talent is geographically restrictive. "},
#  {'polarity': 0.0, 'tweet': 'i am sad that Hatton did not win '},
#  {'polarity': 0.0,
#   'tweet': "i wanna see twilight again. love it, but i don't have the dvd.  oh well... guess i surive."},
#  {'polarity': 1.0, 'tweet': "@SaintAelphaba What's going on this afternoon? "},
#  {'polarity': 0.0,
#   'tweet': 'im soooooooooooooooooooo tired  but in a half hour i can sleep^^'},
#  {'polarity': 1.0, 'tweet': 'Back from europe. Appreciating the states '},
#  {'polarity': 0.0,
#   'tweet': 'Crosby ripped one through varlamov from the circle; shows what he can do when he actually has room to play.  Always passing '},
#  {'polarity': 1.0,
#   'tweet': 'Champagne breakfast  Bubbles went straight to my head tho lol'},
#  {'polarity': 0.0,
#   'tweet': '9:30PM! So I asked my teacher if I had to speak about my project and she said noo! I am so happy. I might have spewed up! '},
#  {'polarity': 0.0,
#   'tweet': '@Ice_Empress Good morning Sexy. California is already sad knowing you are leaving. '},
#  {'polarity': 1.0,
#   'tweet': '@Out_Inc I loooooove dry British humour. Combined with Zombies? Epic win '},
#  {'polarity': 1.0, 'tweet': '@igotpinkeye WILL DO  WILLL DO'},
#  {'polarity': 1.0, 'tweet': '@jonprice Good ole Suzan '},
#  {'polarity': 1.0,
#   'tweet': 'thinks butterfly gardens provide an amazing sense of relaxation. '},
#  {'polarity': 1.0,
#   'tweet': '@shibbychristie  i was sad today, looked at that .gif and no longer was emotionally down.'},
#  {'polarity': 1.0,
#   'tweet': "my disney sing it game loves me  it tells me i'm good, even though i can't sing to save my life."},
#  {'polarity': 1.0, 'tweet': 'night with my mom '},
#  {'polarity': 1.0,
#   'tweet': '@mrgarylee Awww that was nice! Thanks  and of course you are very welcome!'},
#  {'polarity': 0.0,
#   'tweet': '@BenjaminEllis just tried the way back machine, but the sites way too young. '},
#  {'polarity': 1.0, 'tweet': '....I have a non-stop week...and I like it '},
#  {'polarity': 1.0, 'tweet': 'jack johnson sounds good '},
#  {'polarity': 1.0,
#   'tweet': '@SAMeeeJO not yet, but I just bit into a chewy snickers bar, '},
#  {'polarity': 0.0, 'tweet': 'at the hospital getting my friend put in '},
#  {'polarity': 1.0,
#   'tweet': "@bayanijovan  It's working well!!! Congratulations to you and your team!  Konti na lang may pambili na kayo ng couch and you can retu ..."},
#  {'polarity': 1.0,
#   'tweet': '@DamonOldcorn it has been a long time. But there will be another London breakfast that I will be hosting later this year. '},
#  {'polarity': 1.0,
#   'tweet': 'Saw the most awsome sunrise this morning: pinks and oranges over the yellows and purples of the gardens  = AMAZINGNESS  '},
#  {'polarity': 1.0,
#   'tweet': '@traychaney i will def. check out ur book! JD is great! I worked with him on &quot;the kill point.&quot; please give him my best '},
#  {'polarity': 0.0,
#   'tweet': "@boreas26 I know I passed out when I get off sorry b  I'm eating real chicken yummmm"},
#  {'polarity': 1.0,
#   'tweet': '@JimPeake So what you are saying is that &quot;he not quite dead yet?&quot; '},
#  {'polarity': 0.0,
#   'tweet': "guess sometimes like this remind me that i've got to keep my feet on the ground "},
#  {'polarity': 0.0, 'tweet': 'Sick. Headaches. Homework. School tomorrow '},
#  {'polarity': 0.0,
#   'tweet': 'Just been down to the opera house to see the star trek world premire...but missed it '},
#  {'polarity': 0.0,
#   'tweet': "Just woke uppp. Didn't go to the walk, I am sickkk "},
#  {'polarity': 0.0,
#   'tweet': "My littlebrother just got home! I miss him when I'm not here.. "},
#  {'polarity': 1.0,
#   'tweet': "@ddlovato have fun in munich, germany!!  hope u'll be back here on tour one day ;)"},
#  {'polarity': 0.0,
#   'tweet': "Site load rising again. Increased my capacity but it's going up still "},
#  {'polarity': 1.0,
#   'tweet': 'If you look close, you can see me standing behind the left bit of pineapple, got a BBQ today, put this on stereo  http://bit.ly/sDQk'},
#  {'polarity': 1.0, 'tweet': '@CheyanneBrae Happy Sunday to you as well.  '},
#  {'polarity': 0.0,
#   'tweet': "Heaps upset the saints game isn't being televised! "},
#  {'polarity': 1.0,
#   'tweet': "12 hours until Fall Out Boy... I still haven't fallen asleep. I'm THAT excited!! "},
#  {'polarity': 0.0,
#   'tweet': "Out! I'm gonna miss the first hour of the game ...poop "},
#  {'polarity': 1.0,
#   'tweet': '@littlequiz Oh great.. hope u had fun  weddings are gr8 as long as they arent urs LOL.. im doing well.. didnt c u around so thought id ask'},
#  {'polarity': 1.0,
#   'tweet': 'I love waking up in the morning and realizing that I get to go out and do things. Not just stay at home &amp; blow my friends off.  So stoked.'},
#  {'polarity': 0.0, 'tweet': 'Think my head is going to fall off  owww!'},
#  {'polarity': 1.0,
#   'tweet': '@ID7 yep, I reckon 35hrs would be a bit optimistic. Should be a fun drive though '},
#  {'polarity': 1.0, 'tweet': 'lmfao just won zootopia tickets hah '},
#  {'polarity': 0.0, 'tweet': "I can't go out today.... IM SO MAD! "},
#  {'polarity': 0.0, 'tweet': "I don't want to go back to Yakima tomorrow "},
#  {'polarity': 0.0, 'tweet': '@tarek why! '},
#  {'polarity': 0.0, 'tweet': 'B oddkode ugh that sucks im at home '},
#  {'polarity': 1.0,
#   'tweet': 'Work agaaaaiin.  Yesterday I fell in a box. It was pretty spectactular.'},
#  {'polarity': 0.0,
#   'tweet': 'hoping my pup will let me sleep in a little today... that will prob not be the case though '},
#  {'polarity': 1.0,
#   'tweet': 'Daily High: fulfilled LOTS of tanners lotion needs!! Daily Low: NONE! '},
#  ...]

# %% [markdown]
# ## Connecting to db

# %%
DB_NAME = "TWEETS"
COLLECTION_NAME = "tweets_data"
CONNECTION_URL = "mongodb+srv://shubhamhmrm.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import pymongo
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

rec = collection.insert_many(data)

# %%
records = collection.find()
records

# %%
for i,j in enumerate(records):
    print(f"{i}-> {j}")

# %%
df = df.drop(columns="_id")
df.head()
